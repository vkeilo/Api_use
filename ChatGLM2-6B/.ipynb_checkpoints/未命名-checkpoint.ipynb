# %%
import openai
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/miniconda3/envs/api_use/lib/python3.9/site-packages/aiohttp/client_reqrep.py:70
#      69 try:
# ---> 70     import cchardet as chardet
#      71 except ImportError:  # pragma: no cover
#
# ModuleNotFoundError: No module named 'cchardet'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import openai
#
# File ~/miniconda3/envs/api_use/lib/python3.9/site-packages/openai/__init__.py:19
#      15     import aiohttp
#      17     del sys.modules["pkg_resources"]
# ---> 19 from openai.api_resources import (
#      20     Audio,
#      21     ChatCompletion,
#      22     Completion,
#      23     Customer,
#      24     Deployment,
#      25     Edit,
#      26     Embedding,
#      27     Engine,
# ...
